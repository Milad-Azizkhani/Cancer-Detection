# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
images = cv2.imread("/content/AppleScab3.JPG")

# %%
  patches = tf.image.extract_patches(images=tf.expand_dims(images, axis=0),
                           sizes=[1, 16, 16, 1],
                           strides=[1, 16, 16, 1],
                           rates=[1, 1, 1, 1],
                           padding='SAME')

  #expand_dims --> input image matrix must be 4_D

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# in axis in code, we define location of new index.

# %%
tf.expand_dims(images, axis=0)
# Out:
# <tf.Tensor: shape=(1, 256, 256, 3), dtype=uint8, numpy=
# array([[[[  0,   3,   1],
#          [ 62,  76,  74],
#          [ 53,  74,  72],
#          ...,
#          [193, 170, 184],
#          [195, 172, 186],
#          [197, 174, 188]],
#
#         [[  0,   2,   0],
#          [ 61,  78,  75],
#          [ 58,  79,  77],
#          ...,
#          [195, 172, 186],
#          [198, 175, 189],
#          [199, 176, 190]],
#
#         [[  0,   3,   0],
#          [ 58,  79,  76],
#          [ 51,  75,  73],
#          ...,
#          [198, 175, 189],
#          [200, 177, 191],
#          [201, 178, 192]],
#
#         ...,
#
#         [[  4,   1,   3],
#          [ 23,  20,  22],
#          [ 26,  23,  25],
#          ...,
#          [202, 181, 190],
#          [186, 165, 174],
#          [214, 193, 202]],
#
#         [[  4,   1,   3],
#          [ 23,  20,  22],
#          [ 26,  23,  25],
#          ...,
#          [225, 204, 213],
#          [190, 169, 178],
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
patches.shape
# Out:
# TensorShape([1, 16, 16, 768])

# %% [markdown]
# 256 == -1 in this code

# %%
print(tf.reshape(patches,(patches.shape[0],256,768)).shape)
# Out:
# (1, 256, 768)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(0.5,0.5))
plt.imshow(tf.reshape(patches[0,11,1,:],(16,16,3)))

# %%
plt.figure(figsize=(8,8))
k=0

for i in range(16):
  for j in range(16):
    ax = plt.subplot(16, 16, k+1)
    plt.imshow(tf.reshape(patches[0,i,j,:],(16,16,3)))
    plt.axis("off")
    k+=1

# %% [markdown]
# method 2 for print

# %%
patches = tf.reshape(patches,(patches.shape[0],256,768)).shape
